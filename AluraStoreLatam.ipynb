# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeankology/Challenge-amigo-secreto/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
tienda.shape
# Out:
# (2359, 12)

# %%
type(tienda)
# Out:
# pandas.core.frame.DataFrame

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda.isnull()
# Out:
#       Producto  Categoría del Producto  Precio  Costo de envío  \
# 0        False                   False   False           False
# 1        False                   False   False           False
# 2        False                   False   False           False
# 3        False                   False   False           False
# 4        False                   False   False           False
# ...        ...                     ...     ...             ...
# 2354     False                   False   False           False
# 2355     False                   False   False           False
# 2356     False                   False   False           False
# 2357     False                   False   False           False
# 2358     False                   False   False           False
#
#       Fecha de Compra  Vendedor  Lugar de Compra  Calificación  \
# 0               False     False            False         False
# 1               False     False            False         False
# ...

# %%
tienda.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda2.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda3.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda4.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda.fillna(0)
# Out:
#                Producto Categoría del Producto     Precio  Costo de envío  \
# 0     Asistente virtual           Electrónicos   164300.0          6900.0
# 1       Mesa de comedor                Muebles   192300.0          8400.0
# 2         Juego de mesa               Juguetes   209600.0         15900.0
# 3            Microondas      Electrodomésticos   757500.0         41000.0
# 4      Silla de oficina                Muebles   335200.0         20200.0
# ...                 ...                    ...        ...             ...
# 2354          Iphone 15           Electrónicos  1284400.0         66600.0
# 2355          Impresora           Electrónicos   282800.0         15300.0
# 2356      Juego de mesa               Juguetes   122900.0          7200.0
# 2357           Cama box                Muebles   691300.0         35000.0
# 2358         Smartwatch           Electrónicos   195000.0          8600.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# ...

# %%
tienda['Precio']
# Out:
# 0        164300.0
# 1        192300.0
# 2        209600.0
# 3        757500.0
# 4        335200.0
#           ...
# 2354    1284400.0
# 2355     282800.0
# 2356     122900.0
# 2357     691300.0
# 2358     195000.0
# Name: Precio, Length: 2359, dtype: float64

# %%
Facturacion_tienda = tienda['Precio'].sum()

print(f'La Facturacion de la tienda es: {Facturacion_tienda}')
# Out:
# La Facturacion de la tienda es: 1150880400.0

# %%
Facturacion_tienda2 = tienda2['Precio'].sum()

print(f'La Facturacion de la tienda2 es: {Facturacion_tienda2}')
# Out:
# La Facturacion de la tienda2 es: 1116343500.0

# %%
Facturacion_tienda3 = tienda3['Precio'].sum()

print(f'La Facturacion de la tienda3 es: {Facturacion_tienda3}')
# Out:
# La Facturacion de la tienda3 es: 1098019600.0

# %%
Facturacion_tienda4 = tienda4['Precio'].sum()

print(f'La Facturacion de la tienda4 es: {Facturacion_tienda4}')
# Out:
# La Facturacion de la tienda4 es: 1038375700.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tiendas = ['Tienda', 'Tienda2', 'Tienda3', 'Tienda4']
ingresos_por_tienda = [Facturacion_tienda, Facturacion_tienda2, Facturacion_tienda3, Facturacion_tienda4]
colores = ['#1f77b4', '#2E86C1', '#5DADE2', '#AAB7B8']

plt.figure(figsize=(8, 5))
barras = plt.bar(tiendas, ingresos_por_tienda, width=0.6, color=colores)
plt.title('Facturacion Total por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Ingresos(Facturación)')
plt.grid(axis='y', linestyle='--', alpha=0.5)


for barra in barras:
    valory = barra.get_height()
    plt.text(barra.get_x() + barra.get_width()/2, valory, f"${valory:,.0f}", ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_por_categoria_tienda1 = tienda.groupby('Categoría del Producto')['Precio'].sum().reset_index().sort_values('Precio', ascending=False)
ventas_por_categoria_tienda1
# Out:
#     Categoría del Producto       Precio
# 3             Electrónicos  429493500.0
# 2        Electrodomésticos  363685200.0
# 7                  Muebles  187633700.0
# 4   Instrumentos musicales   91299000.0
# 1     Deportes y diversión   39290000.0
# 5                 Juguetes   17995700.0
# 0  Artículos para el hogar   12698400.0
# 6                   Libros    8784900.0

# %%
ventas_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Precio'].sum().reset_index().sort_values('Precio', ascending=False)
ventas_por_categoria_tienda2
# Out:
#     Categoría del Producto       Precio
# 3             Electrónicos  410831100.0
# 2        Electrodomésticos  348567800.0
# 7                  Muebles  176426300.0
# 4   Instrumentos musicales  104990300.0
# 1     Deportes y diversión   34744500.0
# 5                 Juguetes   15945400.0
# 0  Artículos para el hogar   14746900.0
# 6                   Libros   10091200.0

# %%
ventas_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Precio'].sum().reset_index().sort_values('Precio', ascending=False)
ventas_por_categoria_tienda3
# Out:
#     Categoría del Producto       Precio
# 3             Electrónicos  410775800.0
# 2        Electrodomésticos  329237900.0
# 7                  Muebles  201072100.0
# 4   Instrumentos musicales   77380900.0
# 1     Deportes y diversión   35593100.0
# 5                 Juguetes   19401100.0
# 0  Artículos para el hogar   15060000.0
# 6                   Libros    9498700.0

# %%
ventas_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Precio'].sum().reset_index().sort_values('Precio', ascending=False)
ventas_por_categoria_tienda4
# Out:
#     Categoría del Producto       Precio
# 3             Electrónicos  409476100.0
# 2        Electrodomésticos  283260200.0
# 7                  Muebles  192528900.0
# 4   Instrumentos musicales   75102400.0
# 1     Deportes y diversión   33350100.0
# 5                 Juguetes   20262200.0
# 0  Artículos para el hogar   15074500.0
# 6                   Libros    9321300.0

# %%
import matplotlib.pyplot as plt

tiendas = [
    ('Tienda 1', ventas_por_categoria_tienda1),
    ('Tienda 2', ventas_por_categoria_tienda2),
    ('Tienda 3', ventas_por_categoria_tienda3),
    ('Tienda 4', ventas_por_categoria_tienda4)
]

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

colores = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']

for ax, (nombre, df_tienda) in zip(axes.flatten(), tiendas):
    df_tienda_sorted = df_tienda.sort_values('Precio', ascending=False)

    barras = ax.barh(
        df_tienda_sorted['Categoría del Producto'],
        df_tienda_sorted['Precio'],
        color=colores[:len(df_tienda_sorted)]
    )

    ax.set_title(f'Ventas por Categoría - {nombre}', fontsize=14)
    ax.set_xlabel('Ventas Totales')
    ax.set_ylabel('Categoría')


    ax.invert_yaxis()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    for barra in barras:
        valorx = barra.get_width()
        ax.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
import numpy as np

# %%
Calificacion_promedio_tienda1 = tienda.Calificación.mean()
int(Calificacion_promedio_tienda1.round())
# Out:
# 4

# %%
Calificacion_promedio_tienda2 = tienda2.Calificación.mean()
int(Calificacion_promedio_tienda2.round())
# Out:
# 4

# %%
Calificacion_promedio_tienda3 = tienda3.Calificación.mean()
int(Calificacion_promedio_tienda3.round())
# Out:
# 4

# %%
Calificacion_promedio_tienda4 = tienda4.Calificación.mean()
int(Calificacion_promedio_tienda4.round())
# Out:
# 4

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
productos_top_tienda1 = tienda["Producto"].value_counts().head()
productos_top_tienda1
# Out:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64

# %%
productos_top_tienda2 = tienda2["Producto"].value_counts().head()
productos_top_tienda2
# Out:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64

# %%
productos_top_tienda3 = tienda3["Producto"].value_counts().head()
productos_top_tienda3
# Out:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64

# %%
productos_top_tienda4 = tienda4["Producto"].value_counts().head()
productos_top_tienda4
# Out:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64

# %% [markdown]
# ## **Productos Menos Vendidos**

# %%
productos_menos_vendidos_tienda1 = tienda["Producto"].value_counts().tail()
productos_menos_vendidos_tienda1
# Out:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %%
productos_menos_vendidos_tienda2 = tienda2["Producto"].value_counts().tail()
productos_menos_vendidos_tienda2
# Out:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64

# %%
productos_menos_vendidos_tienda3 = tienda3["Producto"].value_counts().tail()
productos_menos_vendidos_tienda3
# Out:
# Producto
# Guitarra eléctrica         38
# Set de vasos               36
# Mochila                    36
# Microondas                 36
# Bloques de construcción    35
# Name: count, dtype: int64

# %%
productos_menos_vendidos_tienda4 = tienda4["Producto"].value_counts().tail()
productos_menos_vendidos_tienda4
# Out:
# Producto
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
Promedio_envio_tienda1 = tienda['Costo de envío'].mean()
int(Promedio_envio_tienda1.round())
# Out:
# 26019

# %%
Promedio_envio_tienda2 = tienda2['Costo de envío'].mean()
int(Promedio_envio_tienda2.round())
# Out:
# 25216

# %%
Promedio_envio_tienda3 = tienda3['Costo de envío'].mean()
int(Promedio_envio_tienda3.round())
# Out:
# 24806

# %%
Promedio_envio_tienda4 = tienda4['Costo de envío'].mean()
int(Promedio_envio_tienda4.round())
# Out:
# 23459

# %%
listaTiendas = ['tienda 1', 'tienda 2', 'tienda 3', 'tienda 4']
costosEnvios = [Promedio_envio_tienda1, Promedio_envio_tienda2, Promedio_envio_tienda3, Promedio_envio_tienda4]
colores = ['#FF0000', '#0000FF', '#00FF00', '#BF00BF']
plt.figure(figsize=(8, 5))
barras = plt.bar(listaTiendas, costosEnvios, width=0.6, color=colores)
plt.title('Costos de envíos promedio por tienda')
plt.xlabel('Tiendas')
plt.ylabel('Promedio de envíos')
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Agrega etiquetas as barras
for barra in barras:
    valory = barra.get_height()
    plt.text(barra.get_x() + barra.get_width()/2, valory, f"${valory:,.0f}", ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Conclusión y Recomendación**
#
# - Mi recomendacion para el señor juan es que no venda ninguna de sus tiendas ya que todas tienen muy buena rentabilidad, los precios son muy similares en la facturación de las 4 tiendas en los productos de electrodomesticos, si quiere aumentar la rentabilidad de su tienda enfoquese en mejorar su fuerte (los electronicos).
